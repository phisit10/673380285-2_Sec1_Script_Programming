# %% [markdown]
# ## Week 4 673380285-2 นายพิสิษฐ์ ทรัพย์อุดมโชติ Sec1_Week4_673380285-2

# %% [markdown]
# # lab4_1.py - Student Management System (List Operations)

# %%
student_names = []

check ='y'
option = 0

while option != 6:
  print("--- Lab 4.1: Student Management System ---")
  print("[1] Add Students")
  print("[2] Find a Student")
  print("[3] Remove a Student")
  print("[4] Sort Students")
  print("[5] Count Students")
  print("[6] exit")

  option = int(input("Enter your choice (1-6): "))

  if(option == 1):
    print("\n[1] Add Students")
    for i in range(0,3): #กำหนดตัวแปรใน loop 👈ต้องทำ
        name = input(f"Enter student name #{i + 1}: ") #กำหนดตัวแปร 👈ต้องทำ
        student_names.append(name)

    print(f"Current list: {student_names}")

  elif(option == 2):
    print("\n[2] Find a Student")
    search_name = input("Enter a name to search for: ")

    if search_namea in student_names:#เขียนเงื่อนไข ถ้าหากมีชื่อในลิส: 👈ต้องทำ
        position = student_names.index(search_name)
        print(f"Found '{search_name}' at index {position}")
    else:
        print(f"'{search_name}' not found in the list")

  elif(option == 3):
    print("\n[3] Remove a Student")
    remove_name = input("Enter a name to remove: ")

    if remove_name in student_names:
        student_names #เติมฟังก์ชัน remove(remove_name) 👈ต้องทำ
        student_names.remove(remove_name)
        print(f"'{remove_name}' has been removed")
    else:
        print(f"'{remove_name}' not found, nothing removed")

    print(f"Updated list: {student_names}")

  elif(option == 4):
    print("\n[4] Sort Students")
    student_names.sort() #เติมฟังก์ชันsort()
    print(f"Sorted list: {student_names}")

  elif(option == 5):
    print("\n[5] Count Students")
    print(f"Total students: {len(student_names)}") #ใช้คำสั่งlen() หาจำนวนนักศึกษาในลิส student_names👈ต้องทำ

  elif(option == 6):
    break

  print()
  #check = str(input("do you want to continute? (y/n) : "))
  #print()
# Out:
# --- Lab 4.1: Student Management System ---
# [1] Add Students
# [2] Find a Student
# [3] Remove a Student
# [4] Sort Students
# [5] Count Students
# [6] exit
# Enter your choice (1-6): 1
#
# [1] Add Students
# Enter student name #1: somchay
# Enter student name #2: somchai
# Enter student name #3: somying
# Current list: ['somchay', 'somchai', 'somying']
#
# --- Lab 4.1: Student Management System ---
# [1] Add Students
# [2] Find a Student
# [3] Remove a Student
# [4] Sort Students
# [5] Count Students
# [6] exit
# Enter your choice (1-6): 2
#
# [2] Find a Student
# Enter a name to search for: somchay
# Found 'somchay' at index 0
#
# --- Lab 4.1: Student Management System ---
# [1] Add Students
# [2] Find a Student
# [3] Remove a Student
# [4] Sort Students
# [5] Count Students
# [6] exit
# Enter your choice (1-6): 2
#
# [2] Find a Student
# Enter a name to search for: somsom
# 'somsom' not found in the list
#
# --- Lab 4.1: Student Management System ---
# [1] Add Students
# [2] Find a Student
# [3] Remove a Student
# [4] Sort Students
# [5] Count Students
# [6] exit
# Enter your choice (1-6): 3
#
# [3] Remove a Student
# Enter a name to remove: somchay
# 'somchay' has been removed
# Updated list: ['somchai', 'somying']
#
# --- Lab 4.1: Student Management System ---
# [1] Add Students
# [2] Find a Student
# [3] Remove a Student
# [4] Sort Students
# [5] Count Students
# [6] exit
# Enter your choice (1-6): 4
#
# [4] Sort Students
# Sorted list: ['somchai', 'somying']
#
# --- Lab 4.1: Student Management System ---
# [1] Add Students
# [2] Find a Student
# [3] Remove a Student
# [4] Sort Students
# [5] Count Students
# [6] exit
# Enter your choice (1-6): 1
#
# [1] Add Students
# Enter student name #1: ad
# Enter student name #2: bob
# Enter student name #3: john
# Current list: ['somchai', 'somying', 'ad', 'bob', 'john']
#
# --- Lab 4.1: Student Management System ---
# [1] Add Students
# [2] Find a Student
# [3] Remove a Student
# [4] Sort Students
# [5] Count Students
# [6] exit
# Enter your choice (1-6): 4
#
# [4] Sort Students
# Sorted list: ['ad', 'bob', 'john', 'somchai', 'somying']
#
# --- Lab 4.1: Student Management System ---
# [1] Add Students
# [2] Find a Student
# [3] Remove a Student
# [4] Sort Students
# [5] Count Students
# [6] exit
# Enter your choice (1-6): 5
#
# [5] Count Students
# Total students: 5
#
# --- Lab 4.1: Student Management System ---
# [1] Add Students
# [2] Find a Student
# [3] Remove a Student
# [4] Sort Students
# [5] Count Students
# [6] exit
# Enter your choice (1-6): 6

# %% [markdown]
# # lab4_2.py - Geometric Calculations (Tuples & Immutability)

# %%
import math

print("--- Lab 4.2: Geometric Calculations ---")

x1 = int(input("enter point1 (x): "))

y1 = int(input("enter point1 (y): "))

x2 = int(input("enter point2 (x): "))

y2 = int(input("enter point2 (y): "))


# 1) กำหนดจุดสองจุดด้วย tuple: point1 และ point2
point1 = (x1, y1) #เติมพิกัด x y ของจุด 👈ต้องทำ
point2 = (x2, y2)  #เติมพิกัด x y ของจุด 👈ต้องทำ


# 2) เข้าถึงค่าพิกัด x, y ของแต่ละจุด
print("\n[1] Access Coordinates")
print(f"Point 1: x = {point1[0]}, y = {point1[1]}") #เติมเลข 0 และ 1 ใน [] 👈ต้องทำ
print(f"Point 2: x = {point2[0]}, y = {point2[1]}") #เติมเลข 0 และ 1 ใน [] 👈ต้องทำ

# 3) ทดลองแก้ไขค่าใน tuple เพื่อแสดงให้เห็นว่า tuple เปลี่ยนแปลงไม่ได้ (immutable)
print("\n[2] Attempt Modification (Immutability Demonstration)")
try:
    point1[0] = 5  # บรรทัดนี้จะทำให้เกิด TypeError เพราะ tuple แก้ไขไม่ได้
except TypeError as e:
    print(f"Error trying to modify tuple: {e}")

# 4) คำนวณระยะห่างระหว่างจุดสองจุดด้วยสูตรระยะทาง
#    distance = sqrt( (x2 - x1)^2 + (y2 - y1)^2 )
print("\n[3] Calculate Distance")
distance = math.sqrt((point2[0] - point1[0]) ** 2 + (point2[1] - point1[1]) ** 2) #เติมเลขตำแหน่งในลิส 0 และ 1 ใน [] ให้ถูกต้อง 👈ต้องทำ
print(f"Distance between point1 {point1} and point2 {point2}: {distance}")
# Out:
# --- Lab 4.2: Geometric Calculations ---
# enter point1 (x): 0
# enter point1 (y): 10
# enter point2 (x): 0
# enter point2 (y): 0
#
# [1] Access Coordinates
# Point 1: x = 0, y = 10
# Point 2: x = 0, y = 0
#
# [2] Attempt Modification (Immutability Demonstration)
# Error trying to modify tuple: 'tuple' object does not support item assignment
#
# [3] Calculate Distance
# Distance between point1 (0, 10) and point2 (0, 0): 10.0

# %% [markdown]
# # Activity 4.1: List vs. Tuple: Scenario Matching
# **สถานการณ์ต่อไปนี้ แต่ละเหตุการณ์ควรใช้ list หรือ tuple เพราะอะไร ?**
#
#
# 1.ข้อมูลอุณหภูมิประจำวันที่มีการบันทึกไว้ตลอดหนึ่งสัปดาห์
#
# **คำตอบ** List ข้อมูลอาจมีการแก้ไขหรืออัปเดต
#
# <br>
#
# 2.ค่าสี RGB ของเฉดสีเฉพาะเฉดหนึ่ง (เช่น สีแดงคือ (255, 0, 0))
#
# **คำตอบ** Tuple เพราะ ค่าสีหนึ่งๆเป็นข้อมูลคงที่
#
# <br>
#
# 3.รายการสินค้าในรถเข็นชอปปิงที่สามารถกดเพิ่มหรือลบออกได้
#
# **คำตอบ** List เพิ่มหรือลบสินค้าได้ต้องแก้ไขข้อมูลได้
# <br>
#
#
#
# 4.รายชื่อวันในหนึ่งสัปดาห์เรียงตามลำดับ (จันทร์ - อาทิตย์)
#
# **คำตอบ** Tuple รายชื่อลำดับวันเป็นข้อมูลคงที่
#
# <br>
#
#
# 5.คะแนนเก็บของนักเรียนจากการส่งงานชุดต่างๆ ซึ่งอาจมีการอัปเดตหรือแก้ไขคะแนนในภายหลังได้
#
# **คำตอบ** List เพราะอาจมีการอัปเดตหรือแก้ไขคะแนนในภายหลังได้
#
# <br>
#
#
# 6.พิกัด GPS ของสถานที่สำคัญหรือจุดแลนด์มาร์กที่ตั้งอยู่กับที่
#
# **คำตอบ** Tuple เพราะพิกัดไม่ควรจะรวน เป็นข้อมูลคงที่

# %% [markdown]
# # Activity 4.2: Interactive To-Do List (using List Operations)

# %%
print("-----My to-do list-----")

todo_list = []

check = 0

while check == 0:
  print("[1] Add a task")
  print("[2] View tasks")
  print("[3] Mark task as complete (remove by index or name)")
  print("[4] Exit")

  option = int(input("Enter your choice (1-4): "))

  if(option == 1):
    print("\n[1] Add a task")
    todo = input(f"Enter task: ")
    todo_list.append(todo)

    print(f"Current list: {todo_list}")
    print()

  elif(option == 2):
    print("\n[2] View tasks")
    print(f"Current task: {todo_list}")
    print()

  elif(option == 3):
    print("\n[2] Mark task as complete (remove by index or name)")

    remove_name = input("Enter a name to remove: ")

    if remove_name in todo_list:
        todo_list.remove(remove_name)
        print(f"'{remove_name}' has been removed")
    else:
        print(f"'{remove_name}' not found, nothing removed")

    print(f"Updated list: {todo_list}")

    print(f"Current task: {todo_list}")
    print()

  elif(option == 4):
    break
# Out:
# -----My to-do list-----
# [1] Add a task
# [2] View tasks
# [3] Mark task as complete (remove by index or name)
# [4] Exit
# Enter your choice (1-4): 1
#
# [1] Add a task
# Enter task: ใบงาน Numerical Method
# Current list: ['ใบงาน Numerical Method']
#
# [1] Add a task
# [2] View tasks
# [3] Mark task as complete (remove by index or name)
# [4] Exit
# Enter your choice (1-4): 1
#
# [1] Add a task
# Enter task: แล็ปOS
# Current list: ['ใบงาน Numerical Method', 'แล็ปOS']
#
# [1] Add a task
# [2] View tasks
# [3] Mark task as complete (remove by index or name)
# [4] Exit
# Enter your choice (1-4): 1
#
# [1] Add a task
# Enter task: Activity วิชา script
# Current list: ['ใบงาน Numerical Method', 'แล็ปOS', 'Activity วิชา script']
#
# [1] Add a task
# [2] View tasks
# [3] Mark task as complete (remove by index or name)
# [4] Exit
# Enter your choice (1-4): 2
#
# [2] View tasks
# Current task: ['ใบงาน Numerical Method', 'แล็ปOS', 'Activity วิชา script']
#
# [1] Add a task
# [2] View tasks
# [3] Mark task as complete (remove by index or name)
# [4] Exit
# Enter your choice (1-4): 3
#
# [2] Mark task as complete (remove by index or name)
# Enter a name to remove: Activity วิชา script
# 'Activity วิชา script' has been removed
# Updated list: ['ใบงาน Numerical Method', 'แล็ปOS']
# Current task: ['ใบงาน Numerical Method', 'แล็ปOS']
#
# [1] Add a task
# [2] View tasks
# [3] Mark task as complete (remove by index or name)
# [4] Exit
# Enter your choice (1-4): 2
#
# [2] View tasks
# Current task: ['ใบงาน Numerical Method', 'แล็ปOS']
#
# [1] Add a task
# [2] View tasks
# [3] Mark task as complete (remove by index or name)
# [4] Exit
# Enter your choice (1-4): 3
#
# [2] Mark task as complete (remove by index or name)
# Enter a name to remove: ใบงาน Numerical Method
# 'ใบงาน Numerical Method' has been removed
# Updated list: ['แล็ปOS']
# Current task: ['แล็ปOS']
#
# [1] Add a task
# [2] View tasks
# [3] Mark task as complete (remove by index or name)
# [4] Exit
# Enter your choice (1-4): 2
#
# [2] View tasks
# Current task: ['แล็ปOS']
#
# [1] Add a task
# [2] View tasks
# [3] Mark task as complete (remove by index or name)
# [4] Exit
# Enter your choice (1-4): 4
